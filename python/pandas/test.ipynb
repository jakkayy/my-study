# %%
import pandas as pd

# %%
co = pd.read_csv("covid_province.csv", encoding='utf-8')
co
# Out:
#             จังหวัด      รวม  น้อยกว่า 1 ปี   1 ปี   2 ปี   3 ปี   4 ปี  \
# 0     กรุงเทพมหานคร  5588222          34808  39431  41803  44389  45504
# 1       สมุทรปราการ  1351479          11150  12175  12765  13390  13719
# 2           นนทบุรี  1276745           9180  10137  10566  11212  11419
# 3          ปทุมธานี  1176412           9664  10561  11151  12160  11978
# 4   พระนครศรีอยุธยา   819088           6714   7209   7536   7784   7699
# ..              ...      ...            ...    ...    ...    ...    ...
# 72             ตรัง   640574           5410   6163   6451   6777   6936
# 73           พัทลุง   523077           4266   4772   5122   5319   5284
# 74          ปัตตานี   726015          11404  11606  12094  12552  12235
# 75             ยะลา   538602           8138   8650   8765   8801   8802
# 76         นราธิวาส   804429          11878  12066  12658  13037  12717
#
#      5 ปี   6 ปี   7 ปี  ...  96 ปี  97 ปี  98 ปี  99 ปี  100 ปี  \
# ...

# %%
start = input("ปีที่เริ่ม : ")
end = input("ปีสิ้นสุด : ")
cols = ['จังหวัด']
for i in range(int(start), int(end)+1):
    cols.append(str(i)+' ปี')

covid = pd.read_csv("covid_province.csv", encoding='utf-8', usecols=cols)
covid
# Out:
#             จังหวัด   1 ปี   2 ปี   3 ปี   4 ปี   5 ปี   6 ปี
# 0     กรุงเทพมหานคร  39431  41803  44389  45504  47745  50717
# 1       สมุทรปราการ  12175  12765  13390  13719  14123  14971
# 2           นนทบุรี  10137  10566  11212  11419  11816  12237
# 3          ปทุมธานี  10561  11151  12160  11978  12444  12891
# 4   พระนครศรีอยุธยา   7209   7536   7784   7699   8065   8675
# ..              ...    ...    ...    ...    ...    ...    ...
# 72             ตรัง   6163   6451   6777   6936   7426   7979
# 73           พัทลุง   4772   5122   5319   5284   5876   6198
# 74          ปัตตานี  11606  12094  12552  12235  12344  12579
# 75             ยะลา   8650   8765   8801   8802   9089   9316
# 76         นราธิวาส  12066  12658  13037  12717  13022  13629
#
# [77 rows x 7 columns]

# %%
co.describe()
# Out:
#                 รวม  น้อยกว่า 1 ปี          1 ปี          2 ปี          3 ปี  \
# count  7.700000e+01      77.000000     77.000000     77.000000     77.000000
# mean   8.595679e+05    7026.272727   7636.636364   8084.649351   8523.987013
# std    7.256862e+05    5167.127596   5730.742939   6069.846081   6411.034424
# min    1.920520e+05    1202.000000   1325.000000   1405.000000   1524.000000
# 25%    4.767270e+05    3723.000000   4016.000000   4318.000000   4527.000000
# 50%    6.702650e+05    5476.000000   6116.000000   6400.000000   6683.000000
# 75%    1.067726e+06    9220.000000  10257.000000  10939.000000  11570.000000
# max    5.588222e+06   34808.000000  39431.000000  41803.000000  44389.000000
#
#                4 ปี          5 ปี          6 ปี          7 ปี          8 ปี  \
# count     77.000000     77.000000     77.000000     77.000000     77.000000
# mean    8617.662338   8950.948052   9472.545455   9681.870130  10367.454545
# ...
